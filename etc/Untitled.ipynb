# %%
from sklearn.datasets import fetch_lfw_people

lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# %%
fig, ax = plt.subplots(1, 10)

for i in range(10):
    ax[i].imshow(lfw_people.images[i], cmap="Greys_r")

# %%
from sklearn.datasets import load_sample_image
dataset = load_sample_image()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-11da8ca11a31> in <module>()
#       1 from sklearn.datasets import load_sample_image
# ----> 2 dataset = load_sample_image()
#
# TypeError: load_sample_image() missing 1 required positional argument: 'image_name'

# %%
dataset.images[1].shape
# Out:
# (427, 640, 3)

# %%
plt.imshow(dataset.images[1])

# %%
from sklearn.datasets import mlcomp, mldata, mldata_filename

mldata.
# mldata.fetch_mldata(dataname='scene')
# # mice = fetch_openml(name='scene', version=4)

# %%
import openml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-9d0b98397986> in <module>()
# ----> 1 import openml
#
# ModuleNotFoundError: No module named 'openml'

# %%
# from skimage.data import moon

# plt.imshow(moon(), cmap="Greys_r")

from skimage.data import immunohistochemistry
from skimage.data import immunohistochemistry

# %%
import matplotlib.cbook as cbook

# %%
cbook.get_sample_data(fname)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-00fb20e022b4> in <module>()
# ----> 1 cbook.get_sample_data()
#
# TypeError: get_sample_data() missing 1 required positional argument: 'fname'

# %%
with cbook.get_sample_data('ada.png') as image_file:
    image = plt.imread(image_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-f982c8316293> in <module>()
# ----> 1 with cbook.get_sample_data('ada.png') as image_file:
#       2     image = plt.imread(image_file)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in get_sample_data(fname, asfileobj)
#     682             return gzip.open(path, mode)
#     683         else:
# --> 684             return open(path, mode)
#     685     else:
#     686         return path
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/dockeruser/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/ada.png'

# %%
from scipy import misc

# %%
misc.face
# Out:
# (108000,)

# %%
from sklearn.datasets import fetch_openml
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-1eac16a8058a> in <module>()
# ----> 1 from sklearn.datasets import fetch_openml
#
# ImportError: cannot import name 'fetch_openml'

# %%
from imageio import imread

humble = imread('imageio:hubble_deep_field.png')

# %%
plt.imshow(humble)
